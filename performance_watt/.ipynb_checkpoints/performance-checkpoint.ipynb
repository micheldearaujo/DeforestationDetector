# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
p05 = pd.read_csv('edge/newperformance/monitoringedgecnn_1.csv')

# %%
p05.head()
# Out:
#                   currentTime  core0Usage(%)  core1Usage(%)  core2Usage(%)  \
# 0  2021-06-18 17:12:39.234218            0.0           33.3            0.0
# 1  2021-06-18 17:13:39.253467            1.1            1.9            2.4
# 2  2021-06-18 17:14:39.295416            5.2            8.6           23.2
# 3  2021-06-18 17:15:39.364367            4.9            9.9            6.2
# 4  2021-06-18 17:16:39.433371            7.6            8.3            6.0
#
#    core3Usage(%)  totalCpuUsage(%)  totalMemory  availableMemory  usedMemory  \
# 0          100.0              75.0   3979698176       3482189824   375930880
# 1            1.0              33.3   3979698176       3482972160   375685120
# 2            7.2               0.0   3979698176       3263430656   593244160
# 3            5.2               0.0   3979698176       3252891648   603783168
# 4            5.5              33.3   3979698176       3245461504   611205120
#
# ...

# %%
plt.plot()
# Out:
# <AxesSubplot:>
